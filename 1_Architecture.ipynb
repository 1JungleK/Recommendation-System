# %% [markdown]
# 推荐算法架构
# - 召回阶段
#     - 召回阶段决定推荐结果上限
#     - 常用算法：
#         - 协同过滤
#         - 基于内容 （文本挖掘）
#         - 基于隐语义
#
# - 排序阶段
#     - 排序逼近推荐结果的上限，决定了最终的推荐结果
#     - CTR预估 （点击率预估 使用逻辑回归 特征为用户特征、产品特征）
#
# - 策略调整
#     - 基于用户行为进行推荐结果调整
#     - 业务背景特殊需求 （商业合作等）
#
# 大量item --> (召回) --> 候选集合 --> (排序) --> 排序集合 --> (规则) --> 展示结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
